# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from ETL.ingesta import obtener_datos

# %%
datos = obtener_datos(inicio=None,fin=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 datos = obtener_datos(inicio=None,fin=None)
#
# File /workspaces/Proyecto-Lab-1/ETL/ingesta.py:39, in obtener_datos(inicio, fin, ticker, user, password, port, host)
#      37 #validacion de fechas
#      38 if not isinstance(inicio, str) or not isinstance(fin, str):
# ---> 39     raise ValueError("Las fechas deben ser cadenas en formato 'YYYY-MM-DD'")
#      40 if inicio >= fin:
#      41     raise ValueError("La fecha de inicio debe ser menor que la fecha de fin")
#
# ValueError: Las fechas deben ser cadenas en formato 'YYYY-MM-DD'

# %%
yhd = obtener_datos_yahoo(start=None,end=None)
frd = obtener_datos_fred(start=None, end=None)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Error al cargar los datos a la base de datos MySQL
