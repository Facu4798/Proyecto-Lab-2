# %%
from ETL.ingesta_fred import obtener_datos_fred
from ETL.ingesta_yahoo import obtener_datos_yahoo

# %%
yhd = obtener_datos_yahoo(inicio=None,fin=None)
frd = obtener_datos_fred(start=None, end=None)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Error downloading data: cannot import name 'cargar_datos' from 'ETL.carga_yahoo' (/workspaces/Proyecto-Lab-1/ETL/carga_yahoo.py)

# %%
type(yhd)
# Out:
# NoneType
